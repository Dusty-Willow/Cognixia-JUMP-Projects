# %%
# %load employee.py
class Employee:

    def __init__ (self, fName, lName, age, birth, employeeId, employmentDate, department, salary, email):
        self.firstName = fName
        self.lastName = lName
        self.age = age
        self.birth = birth
        self.employeeId = employeeId
        self.employmentDate = employmentDate
        self.department = department
        self.salary = salary
        self.email = email

    def toString(self):
        print(f"Employee Name: {self.firstName} {self.lastName}")
        print(f"Employee Age: {self.age}")
        print(f"Employee Birth Date: {self.birth}")
        print(f"Employee ID: {self.employeeId}")
        print(f"Employment Date: {self.employmentDate}")
        print(f"Department: {self.department}")
        print(f"Salary: {self.salary}")
        print(f"Employee Email: {self.email}")
        print("\n")

# %%
# %load manager.py
import json
import employee as emp

employees = []
objectList = []
employeeIdPlaceholder = None

# Methods used for fetching and then displaying list of employees from employees.json
def collector(dict):
    global employees, employeeIdPlaceholder
    employees = dict.keys()
    for key in employees:
        if (key == "0"):
            employeeIdPlaceholder = dict[key]
        else:
            objectList.append(emp.Employee(dict[key]["First Name"], dict[key]["Last Name"], dict[key]["Age"], dict[key]["Birth"], dict[key]["Employee ID"], dict[key]["Employment Date"], dict[key]["Salary"], dict[key]["Department"], dict[key]["Email"]))

def listEmployees():
    global objectList
    empNum = 1
    print("\n")   
    for object in objectList:
        print(f"-----Employee Number {str(empNum)}-----\n")
        object.toString()
        empNum += 1

def displayEmployeeList():
    # Loads employee details from relevant file
    try:
        with open('employees.json', 'rt') as file:
            data = json.load(file)

        collector(data)
        listEmployees()
        generateId()
        # printDict()
    except:
        print("This file doesn't exist.")
# Methods used for fetching and then displaying list of employees from employees.json

def generateEmail(firstName, lastName, birth, id):
    email = ""

    return email

def generateId():
    global employeeIdPlaceholder

    try:
        with open('employees.json', 'rt') as file:
            data = json.load(file)   

        data["0"] = employeeIdPlaceholder + 1

        with open('employees.json', 'w') as file:
            json.dump(data, file, indent=4)
    except:
        print("This file doesn't exist.")

    return str(employeeIdPlaceholder + 1)




displayEmployeeList()
# Out:
# -----Employee Number 1-----
#
# Employee Name: Arthur Pendragon
# Employee Age: 250
# Employee Birth Date: 20-02-1773
# Employee ID: 1
# Employment Date: 12-05-1998
# Department: 60000
# Salary: Security Services
# Employee Email: arthur.pendragon731@camelot.com
#
#
# -----Employee Number 2-----
#
# Employee Name: Monkey D. Luffy
# Employee Age: 28
# Employee Birth Date: 12-09-1994
# Employee ID: 2
# Employment Date: 5-12-2002
# Department: 55000
# Salary: Security Services
# Employee Email: monkey.luffy942@strawhats.com
#
#
# -----Employee Number 3-----
#
# Employee Name: Oliver Garden
# Employee Age: 24
# Employee Birth Date: 15-11-1998
# Employee ID: 3
# Employment Date: 25-02-2000
# Department: 40000
# Salary: Janitorial Services
# Employee Email: oliver.stone983@olivegarden.com
#
#
# -----Employee Number 4-----
#
# Employee Name: Susan Storm
# Employee Age: 30
# Employee Birth Date: 12-05-1993
# Employee ID: 4
# Employment Date: 10-07-2000
# Department: 80000
# Salary: Engineering Services
# Employee Email: susan.storm934@fanfour.com
